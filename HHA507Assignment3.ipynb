# %% [markdown]
# <a href="https://colab.research.google.com/github/nimratmann/datasci_3_eda/blob/main/HHA507Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## loading csv file and displaying the first 10 rows

# %% [markdown]
# Health Medicare Drug Spending Data:
#
# This is a curated collection on Medicare prescription drug spending from 2010 - 2015. Medicare Part B is part of Original Medicare and covers services and supplies that are medically necessary to treat your health condition. This can include outpatient care, preventive services, ambulance services and durable medical equipment. Medicare Part D refers to prescription drug coverage. Medicare is a single-payer national social insurance program administered by the US federal government.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nimratmann/datasci_3_eda/main/datasets/processed/health-medicare-drug-spending.csv')
df.columns
# Out:
# Index(['year', 'brand_name', 'generic_name', 'coverage_type', 'total_spending',
#        'beneficiary_count', 'unit_count', 'beneficiary_cost_share',
#        'total_annual_spending_per_user', 'average_cost_per_unit',
#        'average_annual_beneficiary_cost_share', 'claim_count',
#        'beneficiary_count_lis', 'beneficiary_count_no_lis',
#        'beneficiary_cost_share_lis', 'beneficiary_cost_share_no_lis',
#        'average_beneficiary_cost_share_lis',
#        'average_beneficiary_cost_share_no_lis', 'serialid'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    year brand_name              generic_name coverage_type  total_spending  \
# 0  2010    Abilify              Aripiprazole        Part D    1.225885e+09
# 1  2011    Abilify              Aripiprazole        Part D    1.469590e+09
# 2  2012    Abilify              Aripiprazole        Part D    1.758054e+09
# 3  2013    Abilify              Aripiprazole        Part D    2.107092e+09
# 4  2014    Abilify              Aripiprazole        Part D    2.527319e+09
# 5  2015    Abilify              Aripiprazole        Part D    1.572428e+09
# 6  2010   Abraxane  Paclitaxel Protein-Bound        Part B    1.155539e+08
# 7  2011   Abraxane  Paclitaxel Protein-Bound        Part B    1.213891e+08
# 8  2012   Abraxane  Paclitaxel Protein-Bound        Part B    1.341285e+08
# 9  2013   Abraxane  Paclitaxel Protein-Bound        Part B    2.130076e+08
#
#    beneficiary_count  unit_count  beneficiary_cost_share  \
# 0             338626    71848190             38186677.97
# ...

# %% [markdown]
# ## calculate measures of central tendency

# %%
mean = df['unit_count'].mean()
median = df['unit_count'].median()
mode = df['unit_count'].mode().values[0]

print("Mean: ", mean)
print("Median: ", median)
print("Mode: ", mode)
# Out:
# Mean:  48747853.62326389
# Median:  5723160.5
# Mode:  0

# %%
mean = df['total_spending'].mean()
median = df['total_spending'].median()
mode = df['total_spending'].mode().values[0]

print("Mean: ", mean)
print("Median: ", median)
print("Mode: ", mode)
# Out:
# Mean:  442278443.86253476
# Median:  199428446.32999998
# Mode:  0.0

# %% [markdown]
# ## calculate measures of spread

# %%
range_val = df['unit_count'].max() - df['unit_count'].min()
variance = df['unit_count'].var()
std_deviation = df['unit_count'].std()
iqr = df['unit_count'].quantile(0.75) - df['unit_count'].quantile(0.25)

print("Range: ", range_val)
print("Variance: ", variance)
print ("Standard Deviation: ", std_deviation)
print ("Interquartile Range: ", iqr)
# Out:
# Range:  492962520
# Variance:  9458177325114944.0
# Standard Deviation:  97253161.0032031
# Interquartile Range:  27689462.5

# %%
range_val = df['total_spending'].max() - df['total_spending'].min()
variance = df['total_spending'].var()
std_deviation = df['total_spending'].std()
iqr = df['total_spending'].quantile(0.75) - df['total_spending'].quantile(0.25)

print("Range: ", range_val)
print("Variance: ", variance)
print ("Standard Deviation: ", std_deviation)
print ("Interquartile Range: ", iqr)
# Out:
# Range:  7030633485.8
# Variance:  4.2324632972056774e+17
# Standard Deviation:  650573846.4775292
# Interquartile Range:  505117194.2725

# %% [markdown]
# ## print the results

# %%
print("Measures of Central Tendency:")
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print("\nMeasures of Spread:")
print(f"Range: {range_val}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_deviation}")
print(f"IQR (Interquartile Range): {iqr}")
# Out:
# Measures of Central Tendency:
# Mean: 442278443.86253476
# Median: 199428446.32999998
# Mode: 0.0
#
# Measures of Spread:
# Range: 7030633485.8
# Variance: 4.2324632972056774e+17
# Standard Deviation: 650573846.4775292
# IQR (Interquartile Range): 505117194.2725

# %% [markdown]
# ## create a histogram

# %%
data = {'generic_name': ['Aripiprazole', 'Paclitaxel Protein-Bound', 'Albuterol Sulfate', 'Fluticasone/Salmeterol', 'Everolimus', 'Pemetrexed Disodium', 'Darbepoetin Alfa In Polysorbat', 'Efavirenz/Emtricitab/Tenofovir', 'Bevacizumab', 'Azacitidine'],
        'average_cost_per_unit': [10.5, 20.2, 5.5, 15.1, 18.9, 22.3, 12.7, 9.8, 25.0, 8.4]}

df = pd.DataFrame(data)

# Calculate the frequency of each generic name
generic_counts = df['generic_name'].value_counts()

# Select the top 10 generic names
top_10_generics = generic_counts.head(10).index.tolist()

# Filter the DataFrame to include only the top 10 generic names
filtered_df = df[df['generic_name'].isin(top_10_generics)]

# %%
plt.figure(figsize=(8, 6))
plt.bar(df['generic_name'], df['average_cost_per_unit'], color='pink', edgecolor='black')
plt.title('Average Cost Per Unit by Generic Name')
plt.xlabel('generic_name')
plt.ylabel('average_cost_per_unit')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ## create a histogram

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nimratmann/datasci_3_eda/main/datasets/processed/health-medicare-drug-spending.csv')

plt.figure(figsize=(8, 6))
plt.hist(df['year'], bins=5, color='skyblue', edgecolor='blue')
plt.title('Total Spending 2010-2015, a growing trend')
plt.xlabel('year')
plt.ylabel('Total Spending')
plt.grid(True)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## scatter plot for unit count vs. average cost per unit

# %%
# Scatter plot for Unit Count vs. Average Cost Per Unit
plt.figure(figsize=(8, 6))
plt.scatter(df['average_cost_per_unit'], df['unit_count'], alpha=0.5, color='red')
plt.title('Scatter Plot: Unit Count vs. Average Cost Per Unit ')
plt.xlabel('Average Cost Per Unit ')
plt.ylabel('Unit Count')
plt.xlim(0, max(df['average_cost_per_unit']) * 0.01 )  # Adjust the multiplier as needed
plt.ylim(0, max(df['unit_count']) * 0.01 )  # Adjust the multiplier as needed
plt.grid(True)
plt.show()

# %% [markdown]
# ## identifying correlation relationship

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Select only numeric columns
numerical_columns = df.select_dtypes(include=[np.number])

# Compute correlation matrix for numeric variables
correlation_matrix = numerical_columns.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plot a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=0.5)
plt.title('Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#                                            year  total_spending  \
# year                                   1.000000        0.241483
# total_spending                         0.241483        1.000000
# beneficiary_count                      0.085679        0.399674
# unit_count                             0.041507        0.395136
# beneficiary_cost_share                 0.141610        0.745788
# total_annual_spending_per_user         0.195381        0.083146
# average_cost_per_unit                  0.043911       -0.008631
# average_annual_beneficiary_cost_share  0.131774        0.012500
# claim_count                            0.043566        0.541420
# beneficiary_cost_share_lis             0.001428        0.704333
# beneficiary_cost_share_no_lis          0.145754        0.779318
# average_beneficiary_cost_share_lis     0.125891        0.149786
# average_beneficiary_cost_share_no_lis  0.135077        0.143663
# ...

# %% [markdown]
# ## analysis of correlation based on heatmap

# %% [markdown]
# The correlation coefficient between two variables measures the strength and direction of their linear relationship. In this correlation matrix, the correlation coefficient can take values between -1 and 1, where:
# - A value of 1 indicates a perfect positive linear relationship, meaning that as one variable increases, the other also increases proportionally.
# - A value of -1 indicates a perfect negative linear relationship, meaning that as one variable increases, the other decreases proportionally.
# - A value close to 0 indicates a weak or no linear relationship between the variables.
#
# Looking at the correlation matrix the correlation coefficient between 'total_spending' and 'claim_count,' which is approximately 0.54. This positive correlation suggests that there is a moderate positive linear relationship between the total spending and the claim count. In other words, as the total spending on healthcare increases, the number of claims also tends to increase, and vice versa. This could imply that there might be more claims for healthcare services when the spending is higher.

# %% [markdown]
# # Handling Outliers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## identifying outliers

# %%
variable_of_interest = 'average_beneficiary_cost_share_no_lis'

Q1 = df[variable_of_interest].quantile(0.25)
Q3 = df[variable_of_interest].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df[variable_of_interest] < lower_bound) | (df[variable_of_interest] > upper_bound)]

plt.figure(figsize=(8, 6))
sns.boxplot(x=variable_of_interest, data=df, palette='Set3')
plt.title(f'Boxplot: {variable_of_interest}')
plt.xlabel(variable_of_interest)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outlier Observation
# Low-End Outlier:
# - Generic Name: Gleevec (Imatinib Mesylate)
# - Year: 2010
# - Total Spending: $386,517,300
# - Beneficiary Count: 10,588
#
#
# - Unit Count: 4,167,976
#
# - Beneficiary Cost Share: $29,368,190
#
#
# - Total Annual Spending per User: $36,505.22
#
#
# - Average Cost Per Unit: $92.74
#
# High-End Outlier:
# - Generic Name: Harvoni (Ledipasvir/Sofosbuvir)
# - Year: 2015
# - Total Spending: $7,030,633,000
#
#
# - Beneficiary Count: 75,723
# - Unit Count: 6,237,573
# - Beneficiary Cost Share: $147,344,300
#
#
# - Total Annual Spending per User: $92,846.74
#
#
# - Average Cost Per Unit: $1,127.14
#
#
# These outliers represent data points that are significantly different from the majority of the data in terms of spending, beneficiary count, and average cost per unit. The low-end outlier (Gleevec in 2010) has relatively low spending and cost per unit, while the high-end outlier (Harvoni in 2015) has extremely high spending and cost per unit.

# %% [markdown]
# ## Retain Outliers (No Action) Explanation
#
# In some cases, outliers may carry valuable information or insights. Retaining them can be appropriate if the outliers are genuine data points and not errors. For example, in the case of pharmaceutical/drug spending data, outliers like Harvoni in 2015 might represent significant, real-world events that are relevant to my  analysis.

# %% [markdown]
# # Automated Analysis

# %%
# !pip install pandas-profiling

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('https://raw.githubusercontent.com/nimratmann/datasci_3_eda/main/datasets/processed/health-medicare-drug-spending.csv')

# Generate the EDA report
report = ProfileReport(df)

# %% [markdown]
# ## analysis of profile report:
# The Pandas Profiling Report provides an initial dataset summary. It covers essential statistics like variable count, observation count, missing data count and percentage, duplicates count and percentage, memory usage, and data types (numeric and categorical). Following this, it delves into variable details, showcasing characteristics such as unique values, missing values, infinite values, mean, maximum, minimum, zero values, zero percentage, negative values, and negative percentage, along with memory usage Additionally, the report contains tables displaying missing data information and a sample dataset.
